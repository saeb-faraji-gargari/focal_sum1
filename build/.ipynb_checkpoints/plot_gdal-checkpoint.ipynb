# %%
from osgeo import gdal
import numpy as np
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# 1m_DTM.tif	Makefile	     em.1000.tif  libName_library.a
# CMakeCache.txt	cmake_install.cmake  em_sah.tif   plot_gdal.ipynb
# CMakeFiles	drycreek.tif	     focal_sum

# %%
fn = "1m_DTM.tif"

# %%
ds = gdal.Open(fn)

# %%
print("'ds' type", type(ds))
# Out:
# 'ds' type <class 'osgeo.gdal.Dataset'>

# %%
print("Projection: ", ds.GetProjection())  # get projection
print("Columns:", ds.RasterXSize)  # number of columns
print("Rows:", ds.RasterYSize)  # number of rows
print("Band count:", ds.RasterCount)  # number of bands
# Out:
# Projection:  PROJCS["NAD83 / UTM zone 11N",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4269"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-117],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","26911"]]
# Columns: 790
# Rows: 860
# Band count: 1

# %%
print("GeoTransform", ds.GetGeoTransform())
# Out:
# GeoTransform (519596.3437501494, 1.0, 0.0, 4768706.499882272, 0.0, -1.0)

# %% [markdown]
# The gdal GeoTransform is a tuple that contains six elements. Each GeoTransform element is expalined below in order of its pythonic index (0-5), that is, its position within the tuple.
#
# [0] left X coordinate
# [1] pixel width
# [2] row rotation (usually zero)
# [3] top Y coordinate
# [4] column rotation (usually zero)
# [5] pixel height, this will be negative for north up images

# %%
data_array = ds.GetRasterBand(1).ReadAsArray()
data_array.shape
# Out:
# (860, 790)

# %%
plt.figure(figsize=(5, 5))
plt.imshow(data_array)
plt.colorbar()

# %%
fn_sahand = "drycreek.tif"
ds_sahand = gdal.Open(fn_sahand)

data_array_sahand = ds_sahand.GetRasterBand(1).ReadAsArray()
data_array_sahand.shape

plt.figure(figsize=(5, 5))
plt.imshow(data_array_sahand)
plt.colorbar()

data_array_sahand
# Out:
# array([[1132.2786 , 1131.763  , 1130.3678 , ..., 1493.5098 , 1495.8959 ,
#         1500.6451 ],
#        [1137.9247 , 1137.1047 , 1135.1912 , ..., 1494.6703 , 1497.7571 ,
#         1502.7302 ],
#        [1143.7296 , 1141.6093 , 1138.6403 , ..., 1495.0953 , 1498.6171 ,
#         1504.0288 ],
#        ...,
#        [ 834.41785,  835.96356,  838.8054 , ..., 1266.0476 , 1269.8096 ,
#         1278.055  ],
#        [ 834.41785,  835.42426,  837.86957, ..., 1262.1008 , 1265.3895 ,
#         1274.4287 ],
#        [ 834.1006 ,  834.86774,  836.7736 , ..., 1257.6454 , 1265.9689 ,
#         1271.144  ]], dtype=float32)

# %%
fn_sahand = "em.1000.tif"
ds_sahand = gdal.Open(fn_sahand)

data_array_sahand = ds_sahand.GetRasterBand(1).ReadAsArray()
data_array_sahand.shape

plt.figure(figsize=(5, 5))
plt.imshow(data_array_sahand)
plt.colorbar()

data_array_sahand
# Out:
# array([[-62.364807, -62.364807, -62.364807, ..., -62.364807, -62.364807,
#         -62.364807],
#        [-62.364807, -62.364807, -62.364807, ..., -62.364807, -62.364807,
#         -62.364807],
#        [-62.364807, -62.364807, -62.364807, ..., -62.364807, -62.364807,
#         -62.364807],
#        ...,
#        [-62.364807, -62.364807, -62.364807, ..., -62.364807, -62.364807,
#         -62.364807],
#        [-62.364807, -62.364807, -62.364807, ..., -62.364807, -62.364807,
#         -62.364807],
#        [-62.364807, -62.364807, -62.364807, ..., -62.364807, -62.364807,
#         -62.364807]], dtype=float32)

# %%
fn_sahand = "em_sah.tif"
ds_sahand = gdal.Open(fn_sahand)

data_array_sahand = ds_sahand.GetRasterBand(1).ReadAsArray()
data_array_sahand.shape

plt.figure(figsize=(5, 5))
plt.imshow(data_array_sahand)
plt.colorbar()

data_array_sahand
# Out:
# array([[-561.28326, -561.28326, -561.28326, ..., -561.28326, -561.28326,
#         -561.28326],
#        [-561.28326, -561.28326, -561.28326, ..., -561.28326, -561.28326,
#         -561.28326],
#        [-561.28326, -561.28326, -561.28326, ..., -561.28326, -561.28326,
#         -561.28326],
#        ...,
#        [-561.28326, -561.28326, -561.28326, ..., -561.28326, -561.28326,
#         -561.28326],
#        [-561.28326, -561.28326, -561.28326, ..., -561.28326, -561.28326,
#         -561.28326],
#        [-561.28326, -561.28326, -561.28326, ..., -561.28326, -561.28326,
#         -561.28326]], dtype=float32)
